# %%
from __future__ import print_function
__author__ = "Federica B. Bianco & Zoe E. Martiniak, CUSP NYU 2018"

# %%
import os
import sys

# you can use the numpy library for random number generation: 
# http://docs.scipy.org/doc/numpy/reference/routines.random.html

import numpy as np

# %%
np.random.seed
ReprRand=np.random.randn(2,100)
ReprRand
# Out:
# array([[ 1.19420624, -1.06512328,  0.00922335,  0.95887903,  0.16490719,
#         -0.23969001, -0.61201378, -0.01585326, -1.03565019,  0.58794191,
#         -0.67787638,  0.43658479, -0.37772385,  1.09658746,  0.28221292,
#          0.35705065,  0.56168464,  0.05813804,  2.62249268,  0.11587983,
#         -0.17729869, -1.81410697,  0.27864115, -0.10998656,  1.9570351 ,
#         -0.67365428, -0.50110213, -0.88004898, -0.17950267, -0.21650878,
#         -0.0416796 ,  0.21767777, -1.05853101,  1.3702508 , -0.60298632,
#         -0.31274559,  0.02384767,  0.61143374,  0.87096295, -0.30755296,
#         -0.59573369, -0.14828049, -0.06247575,  0.94714244, -1.11994725,
#          0.39660834,  0.34186108,  0.06812734,  0.39141921, -0.05958656,
#          1.42149795, -0.10961428, -0.4201784 ,  0.98867811,  0.12804441,
#          0.99046335, -0.70973939,  1.15315729,  0.01428894, -2.43791868,
#          0.03276766, -0.84093129,  0.48399215, -0.54475139, -0.20196656,
# ...

# %%
ReprRand.shape
# Out:
# (2, 100)

# %%
np.random.seed
ReprRandAll=np.zeros((50,2,100))
for i in range(50):
    ReprRandAll[i]=np.random.randn(2,100)+i

# %%
np.mean(ReprRandAll[6])
# Out:
# 5.911582108081231

# %%
ReprRandAll.shape
# Out:
# (50, 2, 100)

# %%
import pylab as pl
# %pylab inline
pl.figure(1)
pl.plot(ReprRandAll[1,0])
pl.title('Array 1, Row 1')
pl.ylabel('Array Variations')
pl.xlabel('Element ID')
pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
