# %% [markdown]
# # NYU PUI HOMEWORK 12 - Part 1 - Time Series Analysis
# November 26, 2018
#
# __Author__ = zem232
#
# ### Goal: Examine outliers, trends and periodicity in MTA turnstyle data.
# Continuation of ../HW11_zem232/HW11_zem232_Part1_Subway.ipynb

# %%
from __future__ import print_function, division
import pylab as pl
import numpy as np
import pandas as pd
import os
import sys

from sklearn.ensemble  import RandomForestClassifier as rfc
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import statsmodels.api as sm

# %pylab inline

from IPython.display import Image
from IPython.display import clear_output
pl.rcParams['font.size'] = 20
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mta = np.load(os.getenv('PUIDATA') + "/MTA_Fare.npy").astype(float)
mta [ mta < 0] = np.nan
print('MTA array shape:', mta.shape)
# Out:
# MTA array shape: (600, 23, 194)

# %% [markdown]
# ## 4. Manhattan Stations with Prominent Annual Periodicity

# %% [markdown]
# from the numpy package you will nees only the np.fft.rfft() to take the fourier transform
#
# and
#
# np.fft.rfftfreq() to create a meaningful x axis

# %% [markdown]
# Using the power spectrum" of the Fourier transforms to detect periodicity by squaring the real portion of the Fourier transform output.
#
# # Find periodicity with Fourier Transforms in the time series from HW11. Comment on what you find: what are the most significant periods? Follow instructions in notebook

# %%
len(stations)
# Out:
# 600

# %%
## Summing all ridership type within the mta datacube for each station
stations = np.nansum(mta,axis=1)
## Taking the square of the real portion of the fourier transfer
((np.fft.rfft(stations).real)**2)
period = 3
## plotting
pl.figure(figsize=(15,12))
#pl.xlim((-1,20))
pl.ylim((-0.1e16,0.8e16))
for i in range(len(stations)):
    pl.plot(np.square((np.fft.rfft(stations[i]).real)))
pl.title ("Power Spectrum of MTA Swipes")
pl.xlabel("1/weeks")
pl.ylabel("Power");

# %%
len(stations[3])
# Out:
# 194

# %%
194/52
# Out:
# 3.730769230769231

# %%
f = stations
np.fft.rfftfreq?

# %%
## Summing all ridership type within the mta datacube for each station
stations = np.nansum(mta,axis=1)
## Taking the square of the real portion of the fourier transfer
((np.fft.rfft(stations).real)**2)
period = 3
## plotting
pl.figure(figsize=(20,20))
pl.plot(np.square((np.fft.rfft(stations[400]).real)))
pl.title ("power sopectrum of period=%.2f"%period)
pl.xlabel("?")
pl.ylabel("?");

# %%
abs(np.fft.rfft(stations).real)
(np.fft.rfft(stations[1]).real)**2
# Out:
# array([1.60682967e+13, 3.80330417e+10, 6.24410197e+10, 3.58533933e+09,
#        6.70891834e+10, 1.28430683e+10, 7.45966554e+09, 1.23297996e+10,
#        1.63175949e+10, 7.15562958e+09, 2.66980208e+07, 2.09749879e+10,
#        1.61479329e+10, 1.10558997e+10, 2.65425645e+09, 3.92677045e+08,
#        6.36299997e+09, 2.34091943e+05, 1.85488917e+09, 1.52266270e+09,
#        9.22654307e+09, 6.52213838e+08, 1.04876338e+10, 1.38242357e+09,
#        9.35205658e+07, 1.43706596e+09, 3.94978789e+09, 4.04352141e+09,
#        4.87771196e+07, 4.93827164e+09, 2.00546614e+09, 6.30095159e+06,
#        1.86082811e+08, 1.54378992e+09, 1.04423024e+09, 4.23545582e+08,
#        7.03898736e+09, 2.55862706e+07, 6.64984746e+07, 1.05953620e+09,
#        1.64031415e+08, 3.18971412e+07, 7.95592049e+08, 2.82672155e+09,
#        5.72539090e+08, 4.94992970e+09, 1.27918790e+08, 7.18841384e+08,
#        1.41157244e+09, 4.77836279e+08, 2.33151784e+08, 1.11740696e+08,
